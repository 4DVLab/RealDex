# %%
#抽取出TF，
#抽取出timestamp
#抽取出global positon
#将camera transform合并，一次把rosbag里面全部的数据都给导出
#tracking

# %%
from utils.TFExtract import extract_rosbag_tf
from utils.extract_arm_hand_obj import extract_arm_hand_obj
from utils.extract_exerything_frombag import extract_everything_from_bag
import argparse
#以后可能产生变化的因素全部都要用命令行输入
#之后需要把extract_arm中的urdf位置给变
#ros_path_prefix 变
# pinhole_camera_parameters_path
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.8/dist-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--folder_path', default=None, type=str,
                        help='training stage')
    parser.add_argument('--bag_name', default=None, type=str,)
    return parser.parse_args()

# %%
if __name__ == "__main__":
    # args = get_args()
    # folder_path = args.folder_path
    # bag_name = args.bag_name
    folder_path = "/media/tony/新加卷/yyx_tmp/"
    bag_name = "slow_hand"
    
    extract_rosbag_tf(folder_path,bag_name)
    extract_arm_hand_obj(folder_path,bag_name)
    extract_everything_from_bag(folder_path,bag_name)
# Out:
# begin to extract the rosbag tf
# 10960it [00:19, 570.95it/s]
# /media/tony/新加卷/yyx_tmp//slow_hand/TF/
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb Cell 4 line 8
#       <a href='vscode-notebook-cell:/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> folder_path = "/media/tony/新加卷/yyx_tmp/"
#       <a href='vscode-notebook-cell:/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> bag_name = "slow_hand"
# ----> <a href='vscode-notebook-cell:/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> extract_rosbag_tf(folder_path,bag_name)
#       <a href='vscode-notebook-cell:/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> extract_arm_hand_obj(folder_path,bag_name)
#      <a href='vscode-notebook-cell:/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/data_process.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> extract_everything_from_bag(folder_path,bag_name)
#
# File ~/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/utils/TFExtract.py:61, in extract_rosbag_tf(folder_path, bag_name)
#      59 convert_dict_values_to_float(data_write)
#      60 print(output_path)
# ---> 61 write_dict_to_files(data_write,output_path)
#
# File ~/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/utils/TFExtract.py:21, in write_dict_to_files(dictionary, write_path)
#      19 for key, value in dictionary.items():
#      20     filename = write_path + str(key) + ".txt"  # 以键名作为文件名，添加.txt扩展名
# ---> 21     with open(filename, 'w+') as file:
#      22         for sublist in value:
#      23             line = ' '.join(map(str, sublist))  # 将第二层列表中的元素转换为字符串，并以空格分隔
#
# OSError: [Errno 22] Invalid argument: '/media/tony/新加卷/yyx_tmp//slow_hand/TF/cam0_camera_base -> cam0_camera_body.txt'
