# %%
transform_list = {}
def change(transform):
    transform["1"] = "set"
change(transform_list)

def change_2(transform):
    transform["2"] = "set"

change_2(transform_list)
print(transform_list)
# Out:
# {'1': 'set', '2': 'set'}
