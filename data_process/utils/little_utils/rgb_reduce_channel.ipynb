# %%
import cv2,os
import numpy as np

# %%
folder_path = "/home/tony/mine/Projects/ArmHandVis/HandVersion/HandArmFiles/ARM_HAND_URDF/banana/cam0/rgb/image_raw/"
for file_name in os.listdir(folder_path):
    if file_name.endswith(".png"):
        file_path = folder_path + file_name
        img = cv2.imread(file_path,cv2.IMREAD_UNCHANGED)
        cv2.imwrite(file_path,img[:,:,:3])
